# %%
import matplotlib.pyplot as plt 
import xarray as xr

# ds = xr.open_dataset(r"/mnt/d/project/01_ENSO/01_data/01_raw/godas/GODAS_mlotst.nc").isel(time=-1)
# ds['dbss_obml'].plot()

# ds = xr.open_dataset(r"/mnt/d/project/01_ENSO/01_data/01_raw/godas/GODAS_sos.nc").isel(time=-1)
# ds['salt'].plot()

# ds = xr.open_dataset(r"/mnt/d/project/01_ENSO/01_data/01_raw/godas/GODAS_uo.nc").isel(time=-1)
# ds['ucur'].plot()

ds = xr.open_dataset(r"/mnt/d/project/01_ENSO/01_data/01_raw/era5/ERA5_psl.nc").isel(valid_time=-1)
ds['msl'].plot()

print(ds)
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:     (latitude: 481, longitude: 1440)
# Coordinates:
#     number      int64 8B ...
#     valid_time  datetime64[ns] 8B 2025-12-01
#   * latitude    (latitude) float64 4kB 60.0 59.75 59.5 ... -59.5 -59.75 -60.0
#   * longitude   (longitude) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
#     expver      <U4 16B ...
# Data variables:
#     msl         (latitude, longitude) float32 3MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-02-02T09:22 GRIB to CDM+CF via cfgrib-0.9.1...
